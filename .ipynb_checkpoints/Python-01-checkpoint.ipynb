# %%
import pandas as pd

# %%
retail_data = pd.read_csv('online_retail2.csv')

# %%
retail_data
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1        489434    79323P                   PINK CHERRY LIGHTS        12
# 2        489434    79323W                  WHITE CHERRY LIGHTS        12
# 3        489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4        489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...         ...       ...                                  ...       ...
# 1067366  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 1067367  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 1067368  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 1067369  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 1067370  581587      POST                              POSTAGE         1
#
#                  InvoiceDate  Price  Customer ID         Country
# ...

# %%
retail_data.columns
# Out:
# Index(['Invoice', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'Price', 'Customer ID', 'Country'],
#       dtype='object')

# %%
def status(person):
    if(person >=20):
        print('adult')
    elif (person >= 14):
       print( 'teenager')
    else :print('Child' )

# %%
status(haytham)
# Out:
# adult

# %%
haytham=32
mariam =23
frank=15
leo=12
sarah=8

# %%
def ukornot(country):
    if(country=='United Kingdom'):
        return(True)
    else: return(False)

# %%
retail_data['uk']=retail_data['Country'].map(ukornot)

# %%
retail_data.uk.value_counts()
# Out:
# uk
# True     981330
# False     86041
# Name: count, dtype: int64

# %%
first_10= retail_data.iloc[0:10,:]

# %%
first_10['uk1']=np.nan
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 first_10['uk1']=np.nan
#
# NameError: name 'np' is not defined

# %%
first_10.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#            InvoiceDate  Price  Customer ID         Country    uk
# 0  2009-12-01 07:45:00   6.95      13085.0  United Kingdom  True
# 1  2009-12-01 07:45:00   6.75      13085.0  United Kingdom  True
# 2  2009-12-01 07:45:00   6.75      13085.0  United Kingdom  True
# 3  2009-12-01 07:45:00   2.10      13085.0  United Kingdom  True
# 4  2009-12-01 07:45:00   1.25      13085.0  United Kingdom  True

# %%
first_20.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#            InvoiceDate  Price  Customer ID         Country    uk
# 0  2009-12-01 07:45:00   6.95      13085.0  United Kingdom  True
# 1  2009-12-01 07:45:00   6.75      13085.0  United Kingdom  True
# 2  2009-12-01 07:45:00   6.75      13085.0  United Kingdom  True
# 3  2009-12-01 07:45:00   2.10      13085.0  United Kingdom  True
# 4  2009-12-01 07:45:00   1.25      13085.0  United Kingdom  True

# %%
first_20= retail_data.iloc[0:25,:]

# %%
first_20.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#            InvoiceDate  Price  Customer ID         Country    uk
# 0  2009-12-01 07:45:00   6.95      13085.0  United Kingdom  True
# 1  2009-12-01 07:45:00   6.75      13085.0  United Kingdom  True
# 2  2009-12-01 07:45:00   6.75      13085.0  United Kingdom  True
# 3  2009-12-01 07:45:00   2.10      13085.0  United Kingdom  True
# 4  2009-12-01 07:45:00   1.25      13085.0  United Kingdom  True

# %%
retail_data
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1        489434    79323P                   PINK CHERRY LIGHTS        12
# 2        489434    79323W                  WHITE CHERRY LIGHTS        12
# 3        489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4        489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...         ...       ...                                  ...       ...
# 1067366  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 1067367  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 1067368  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 1067369  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 1067370  581587      POST                              POSTAGE         1
#
#                  InvoiceDate  Price  Customer ID         Country     uk
# ...

# %%
first_20 = retail_data.head(25)

# %%
first_20
# Out:
#    Invoice StockCode                          Description  Quantity  \
# 0   489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1   489434    79323P                   PINK CHERRY LIGHTS        12
# 2   489434    79323W                  WHITE CHERRY LIGHTS        12
# 3   489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4   489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# 5   489434     22064           PINK DOUGHNUT TRINKET POT         24
# 6   489434     21871                  SAVE THE PLANET MUG        24
# 7   489434     21523   FANCY FONT HOME SWEET HOME DOORMAT        10
# 8   489435     22350                            CAT BOWL         12
# 9   489435     22349       DOG BOWL , CHASING BALL DESIGN        12
# 10  489435     22195         HEART MEASURING SPOONS LARGE        24
# 11  489435     22353   LUNCHBOX WITH CUTLERY FAIRY CAKES         12
# 12  489436    48173C                DOOR MAT BLACK FLOCK         10
# ...
